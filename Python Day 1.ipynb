# %%
# variable

Name = "Akash Vaiashya"
print(Name)
# Out:
# Akash Vaiashya

# %%
# variable

name = "akash"
print(name)
# Out:
# akash

# %%
# variable

age = 18
print(age)
# Out:
# 18

# %%
# variable

Date = "16/07/2026"
print(Date)
# Out:
# 16/07/2026

# %%
# variable

Day = "Thursday"
print(Day)
# Out:
# Thursday

# %%
# variable

Message = "give me a pen"
print(Message)
# Out:
# give me a pen

# %%
# variable

Name = "akash"
result = Name.upper()
print(result)
# Out:
# AKASH

# %%
# variable

Name="AKASH"
result = Name.lower()
print(result)
# Out:
# akash

# %%
first_name = "Rahul"
last_name = "sharma"
print(first_name + " " + last_name)
# Out:
# Rahul sharma

# %%
name = "helloworld"
print(name[:5])
print(name[5:])
# Out:
# hello
# world

# %%
# enter the number

a = int(input("enter the num1 :"))
b = int(input("enter the num2 :"))
print(a+b)
# Out:
# enter the num1 : 36
# enter the num2 : 44
# 80

# %%
# enter the number

a = int(input("enter the num1 :"))
b = int(input("enter the num2 :"))
print(a-b)
# Out:
# enter the num1 : 44
# enter the num2 : 36
# 8

# %%
# enter the number

a = int(input("enter the num1 :"))
b = int(input("enter the num2 :"))
print(a>b)
# Out:
# enter the num1 : 44
# enter the num2 : 36
# True

# %%
# enter the number

a = int(input("enter the num1 :"))
b = int(input("enter the num2 :"))
print(a<b)
# Out:
# enter the num1 : 44
# enter the num2 : 36
# False

# %%
# type of function

a = 45
print(type(a))
# Out:
# <class 'int'>

# %%
# type of function

a = "45"
print(type(a))
# Out:
# <class 'str'>

# %%
# type of function

a = True
b = False
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
# type of function

a = 45 +5j
print(type(a))
# Out:
# <class 'complex'>

# %%
# type of function

a = 45.5
print(type(a))
# Out:
# <class 'float'>
