# %%
# operation of loop

age = 20
if age>=18:
   print("you can vote")
else:
   print("you can not vote")
# Out:
# you can vote

# %%
num = 5
if num%2== 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
a =int(input("enter the num"))
if a % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter the num 5
# odd

# %%
i = 0
while i<5:
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
row = 5 

for i in range(1,row +1):
    print(" " * (row -i) +"*" *(2 * i -1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
def greet():
    print("welcome to python")
greet()
# Out:
# welcome to python

# %%
vegetable =["patato","tamato"]
vegetable.append("onion")
print(vegetable)
# Out:
# ['patato', 'tamato', 'onion']

# %%
a = int(input("enter the first num :"))
b = int(input("enter the second num :"))
if  a == b:
  print("equal")
else:
   print("not equal")
# Out:
# enter the first num : 4
# enter the second num : 8
# not equal

# %%
vegetable =["patato","tamato"]
vegetable.remove("patato")
print(vegetable)
# Out:
# ['tamato']

# %%
fruits = ["apple","banana","mango"] 

for fruit in fruits:
  
    print(fruit)
# Out:
# apple
# banana
# mango

# %%
fruits = ["apple","banana","gauva","pineapple","mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'gauva', 'pineapple', 'mango']

# %%
fruits = ["apple","banana","gauva","pineapple","mango"]
fruits.append("pine")
print(fruits)
# Out:
# ['apple', 'banana', 'gauva', 'pineapple', 'mango', 'pine']

# %%
fruits = ["apple","banana","gauva","pineapple","mango"]
print("total fruits:",len(fruits))
# Out:
# total fruits: 5

# %%
fruits = ["apple","banana","gauva","pineapple","mango"]
print("first element:",fruits[0])
print("last element:",fruits[-1])
# Out:
# first element: apple
# last element: mango

# %%
number = [20,30,40,50]
number.sort()
print(number)
# Out:
# [20, 30, 40, 50]

# %%
number = [90,80,70,60]
number.sort()
print(number)
# Out:
# [60, 70, 80, 90]

# %%
number = [90,80,70,60]
number = max(number)
print(number)
# Out:
# 90

# %%
number = [90,80,70,60]
number.sort(reverse=True)
print(number)
# Out:
# [90, 80, 70, 60]

# %%
number = [90,80,70,60]
number = max(number)
print(number)
# Out:
# 90
